# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/Vidhut Sharma/Downloads/Cleaned Data(edited).csv")
df
# Out:
#             ID  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0            0  2008      1           3          4     1829        1755
# 1            1  2008      1           3          4     1937        1830
# 2            2  2008      1           3          4     1644        1510
# 3            3  2008      1           3          4     1452        1425
# 4            4  2008      1           3          4     1323        1255
# ...        ...   ...    ...         ...        ...      ...         ...
# 685729  685729  2008      6          13          5     1609        1535
# 685730  685730  2008      6          14          6     1616        1535
# 685731  685731  2008      6          17          2     1617        1535
# 685732  685732  2008      6          22          7     1607        1535
# 685733  685733  2008      6          23          1     1608        1535
#
#         ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 685734 entries, 0 to 685733
# Data columns (total 30 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 685734 non-null  int64
#  1   Year               685734 non-null  int64
#  2   Month              685734 non-null  int64
#  3   DayofMonth         685734 non-null  int64
#  4   DayOfWeek          685734 non-null  int64
#  5   DepTime            685734 non-null  int64
#  6   CRSDepTime         685734 non-null  int64
#  7   ArrTime            685734 non-null  int64
#  8   CRSArrTime         685734 non-null  int64
#  9   UniqueCarrier      685734 non-null  object
#  10  FlightNum          685734 non-null  int64
#  11  TailNum            685734 non-null  object
#  12  ActualElapsedTime  685734 non-null  int64
#  13  CRSElapsedTime     685734 non-null  int64
#  14  AirTime            685734 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID      Year          Month     DayofMonth      DayOfWeek  \
# count  685734.000000  685734.0  685734.000000  685734.000000  685734.000000
# mean   342866.500000    2008.0       3.372273      15.346483       3.979874
# std    197954.499084       0.0       1.711575       8.927778       1.970784
# min         0.000000    2008.0       1.000000       1.000000       1.000000
# 25%    171433.250000    2008.0       2.000000       7.000000       2.000000
# 50%    342866.500000    2008.0       3.000000      15.000000       4.000000
# 75%    514299.750000    2008.0       5.000000      23.000000       5.000000
# max    685733.000000    2008.0       6.000000      31.000000       7.000000
#
#              DepTime     CRSDepTime        ArrTime     CRSArrTime  \
# count  685734.000000  685734.000000  685734.000000  685734.000000
# mean     1560.354417    1489.506097    1619.628986    1651.464867
# std       452.558818     421.453742     579.883767     461.146295
# ...

# %%
df.isnull().sum()
# Out:
# ID                   0
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %%
#Drop the columns
df.drop(["ID","UniqueCarrier","TailNum","Origin","Dest","CancellationCode"],axis =1,inplace =True)

# %%
X = df.drop("Cancelled",axis =1)
y = df["Cancelled"]

# %%
#Splitting the data into train and test split to build Naive Bayes Model
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=42)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((480013, 23), (480013,), (205721, 23), (205721,))

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(X_train,y_train)
# Out:
# 0.5008176861876658

# %%
y_train_pred = gnb.predict(X_train)
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.26    240116
#            1       0.50      0.83      0.62    239897
#
#     accuracy                           0.50    480013
#    macro avg       0.50      0.50      0.44    480013
# weighted avg       0.50      0.50      0.44    480013

# %%
Confusion_MatrixData = confusion_matrix(y_train,y_train_pred)

#Calculating Accuracy,Percision,Recall and F1-Score
Accuracy = (Confusion_MatrixData[1][0] + Confusion_MatrixData[0][0])/(Confusion_MatrixData[0][0] + Confusion_MatrixData[0][1] + Confusion_MatrixData[1][0]+ Confusion_MatrixData[1][1])
Senstivity = (Confusion_MatrixData[1][1]) /  (Confusion_MatrixData[1][1] + Confusion_MatrixData[1][0])
Precision = (Confusion_MatrixData[1][1]) / (Confusion_MatrixData[1][1] + (Confusion_MatrixData[0][1])) 
F1Score = (2 * Senstivity * Precision)/(Senstivity + Precision)

# %%
Performance_Metrics = pd.DataFrame({"Model": "Naive Bayes[Train]","Accuracy": [Accuracy],"Precision":[Precision],"Recall":[Senstivity],"F1Score":[F1Score]})
Performance_Metrics
# Out:
#                 Model  Accuracy  Precision    Recall   F1Score
# 0  Naive Bayes[Train]  0.173516   0.500357  0.827451  0.623615

# %%
#Checking test data performance
y_pred_test = gnb.predict(X_test)
y_pred_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.26    103081
#            1       0.50      0.83      0.62    102640
#
#     accuracy                           0.50    205721
#    macro avg       0.50      0.50      0.44    205721
# weighted avg       0.50      0.50      0.44    205721

# %%
Confusion_MatrixData = confusion_matrix(y_test,y_pred_test)

#Calculating Accuracy,Percision,Recall and F1-Score
Accuracy = (Confusion_MatrixData[1][0] + Confusion_MatrixData[0][0])/(Confusion_MatrixData[0][0] + Confusion_MatrixData[0][1] + Confusion_MatrixData[1][0]+ Confusion_MatrixData[1][1])
Senstivity = (Confusion_MatrixData[1][1]) /  (Confusion_MatrixData[1][1] + Confusion_MatrixData[1][0])
Precision = (Confusion_MatrixData[1][1]) / (Confusion_MatrixData[1][1] + (Confusion_MatrixData[0][1])) 
F1Score = (2 * Senstivity * Precision)/(Senstivity + Precision)

# %%
Performance_Metrics_test = pd.DataFrame({"Model": "Naive Bayes[Test]","Accuracy": [Accuracy],"Precision":[Precision],"Recall":[Senstivity],"F1Score":[F1Score]})
Performance_Metrics_test
# Out:
#                Model  Accuracy  Precision    Recall   F1Score
# 0  Naive Bayes[Test]  0.173954   0.498661  0.825604  0.621774

# %%
pd.concat([Performance_Metrics,Performance_Metrics_test],axis =0)
# Out:
#                 Model  Accuracy  Precision    Recall   F1Score
# 0  Naive Bayes[Train]  0.173516   0.500357  0.827451  0.623615
# 0   Naive Bayes[Test]  0.173954   0.498661  0.825604  0.621774
