# %%
import pandas as pd

# %%
data=pd.read_csv(r'ShortenedDelayFlight.csv')

# %%
data
# Out:
#         Unnamed: 0      ID  Year  Month  DayofMonth  DayOfWeek  DepTime  \
# 0                0       0  2008      1           3          4     1829
# 1                1       1  2008      1           3          4     1937
# 2                2       2  2008      1           3          4     1644
# 3                3       3  2008      1           3          4     1452
# 4                4       4  2008      1           3          4     1323
# ...            ...     ...   ...    ...         ...        ...      ...
# 685729      685729  685729  2008      6          13          5     1609
# 685730      685730  685730  2008      6          14          6     1616
# 685731      685731  685731  2008      6          17          2     1617
# 685732      685732  685732  2008      6          22          7     1607
# 685733      685733  685733  2008      6          23          1     1608
#
#         CRSDepTime  ArrTime  CRSArrTime  ... TaxiIn  TaxiOut Cancelled  \
# ...

# %%
data.shape
# Out:
# (685734, 31)

# %%
for col in data.columns:
    print(col)
# Out:
# Unnamed: 0
# ID
# Year
# Month
# DayofMonth
# DayOfWeek
# DepTime
# CRSDepTime
# ArrTime
# CRSArrTime
# UniqueCarrier
# FlightNum
# TailNum
# ActualElapsedTime
# CRSElapsedTime
# AirTime
# ArrDelay
# DepDelay
# Origin
# Dest
# Distance
# TaxiIn
# TaxiOut
# Cancelled
# CancellationCode
# Diverted
# CarrierDelay
# WeatherDelay
# NASDelay
# SecurityDelay
# LateAircraftDelay

# %%
import matplotlib.pyplot as plt

# %%
data["TaxiOut"]
# Out:
# 0         10
# 1          7
# 2          8
# 3          8
# 4          9
#           ..
# 685729    15
# 685730    11
# 685731    17
# 685732    12
# 685733    10
# Name: TaxiOut, Length: 685734, dtype: int64

# %%
taxiout=data.iloc[:,22]
year=data.iloc[:,2]
month=data.iloc[:,3]

# %%
taxiout
# Out:
# 0         10
# 1          7
# 2          8
# 3          8
# 4          9
#           ..
# 685729    15
# 685730    11
# 685731    17
# 685732    12
# 685733    10
# Name: TaxiOut, Length: 685734, dtype: int64

# %%
plt.scatter(month,taxiout)
plt.show()

# %%
import numpy as np

# %%
median=np.median(data.iloc[:,22])

# %%
median
# Out:
# 16.0

# %%
threshold = 3
mode = data.iloc[:,21].mode()
median = data.iloc[:,21].median()
z_scores = (data.iloc[:,21] - median) / data.iloc[:,21].std()
data['taxiout'] = np.where(np.abs(z_scores) > threshold, mode, data.iloc[:,21])

# %%
data
# Out:
#         Unnamed: 0      ID  Year  Month  DayofMonth  DayOfWeek  DepTime  \
# 0                0       0  2008      1           3          4     1829
# 1                1       1  2008      1           3          4     1937
# 2                2       2  2008      1           3          4     1644
# 3                3       3  2008      1           3          4     1452
# 4                4       4  2008      1           3          4     1323
# ...            ...     ...   ...    ...         ...        ...      ...
# 685729      685729  685729  2008      6          13          5     1609
# 685730      685730  685730  2008      6          14          6     1616
# 685731      685731  685731  2008      6          17          2     1617
# 685732      685732  685732  2008      6          22          7     1607
# 685733      685733  685733  2008      6          23          1     1608
#
#         CRSDepTime  ArrTime  CRSArrTime  ... TaxiOut  Cancelled  \
# ...

# %%
plt.scatter(month,taxiout)

# %%
plt.show()

# %%
median = np.median(data.iloc[:,21])

# identify outliers using Z-score method
threshold = 3
z_scores = (data.iloc[:,21] - median) / data.iloc[:,21].std()
taxiout = np.where(np.abs(z_scores) > threshold, median, data.iloc[:,21])

# %%
taxiout
# Out:
# array([3., 3., 6., ..., 7., 5., 6.])

# %%
plt.scatter(month,taxiout)

# %%
plt.show()

# %%
data
# Out:
#         Unnamed: 0      ID  Year  Month  DayofMonth  DayOfWeek  DepTime  \
# 0                0       0  2008      1           3          4     1829
# 1                1       1  2008      1           3          4     1937
# 2                2       2  2008      1           3          4     1644
# 3                3       3  2008      1           3          4     1452
# 4                4       4  2008      1           3          4     1323
# ...            ...     ...   ...    ...         ...        ...      ...
# 685729      685729  685729  2008      6          13          5     1609
# 685730      685730  685730  2008      6          14          6     1616
# 685731      685731  685731  2008      6          17          2     1617
# 685732      685732  685732  2008      6          22          7     1607
# 685733      685733  685733  2008      6          23          1     1608
#
#         CRSDepTime  ArrTime  CRSArrTime  ... TaxiOut  Cancelled  \
# ...
