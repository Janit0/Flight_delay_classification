# %%
import pandas as pd

# %%
data=pd.read_csv(r'Downloads\ShortenedDelayFlight.csv')

# %%
data
# Out:
#         Unnamed: 0      ID  Year  Month  DayofMonth  DayOfWeek  DepTime  \
# 0                0       0  2008      1           3          4     1829
# 1                1       1  2008      1           3          4     1937
# 2                2       2  2008      1           3          4     1644
# 3                3       3  2008      1           3          4     1452
# 4                4       4  2008      1           3          4     1323
# ...            ...     ...   ...    ...         ...        ...      ...
# 685729      685729  685729  2008      6          13          5     1609
# 685730      685730  685730  2008      6          14          6     1616
# 685731      685731  685731  2008      6          17          2     1617
# 685732      685732  685732  2008      6          22          7     1607
# 685733      685733  685733  2008      6          23          1     1608
#
#         CRSDepTime  ArrTime  CRSArrTime  ... TaxiIn  TaxiOut Cancelled  \
# ...

# %%
arrdelay=data.iloc[:,16]

# %%
arrdelay
# Out:
# 0         34
# 1         57
# 2         80
# 3         15
# 4         16
#           ..
# 685729    27
# 685730    39
# 685731    47
# 685732    26
# 685733    18
# Name: ArrDelay, Length: 685734, dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Year', 'Month', 'DayofMonth', 'DayOfWeek',
#        'DepTime', 'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier',
#        'FlightNum', 'TailNum', 'ActualElapsedTime', 'CRSElapsedTime',
#        'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest', 'Distance',
#        'TaxiIn', 'TaxiOut', 'Cancelled', 'CancellationCode', 'Diverted',
#        'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay',
#        'LateAircraftDelay'],
#       dtype='object')

# %%
carrierdelay=data.iloc[:,26]
weatherdelay=data.iloc[:,27]
nasdelay=data.iloc[:,28]
securitydelay=data.iloc[:,29]
lateaircraftdelay=data.iloc[:,30]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              2
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %%
zero_rows=data[arrdelay==0]

# %%
zero_rows
# Out:
#         Unnamed: 0      ID  Year  Month  DayofMonth  DayOfWeek  DepTime  \
# 12703        12703   12703  2008      1          25          5     1440
# 25406        25406   25406  2008      1           9          3     1215
# 38109        38109   38109  2008      1          19          6     1255
# 50812        50812   50812  2008      1          31          4     1541
# 63515        63515   63515  2008      1          19          6     1417
# 76218        76218   76218  2008      1          26          6     1423
# 88921        88921   88921  2008      1          21          1     1445
# 101624      101624  101624  2008      1           9          3     1231
# 114327      114327  114327  2008      1           2          3     2319
# 127030      127030  127030  2008      2          10          7     1409
# 139733      139733  139733  2008      2          26          2     1819
# 152436      152436  152436  2008      2          23          6      750
# ...

# %%
addition=carrierdelay+weatherdelay+nasdelay+

# %%
filled_column=arrdelay.where(arrdelay!=0,arrdelay+carrierdelay+weatherdelay+nasdelay+securitydelay+lateaircraftdelay)

# %%
arrdelay=filled_column

# %%
arrdelay
# Out:
# 0         34
# 1         57
# 2         80
# 3         15
# 4         16
#           ..
# 685729    27
# 685730    39
# 685731    47
# 685732    26
# 685733    18
# Name: ArrDelay, Length: 685734, dtype: int64

# %%
zero_rows=data[arrdelay==0]

# %%
zero_rows
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Out:
# 0          2
# 1         10
# 2          8
# 3          3
# 4          0
#           ..
# 685729    27
# 685730    11
# 685731     0
# 685732     1
# 685733    18
# Name: CarrierDelay, Length: 685734, dtype: int64
